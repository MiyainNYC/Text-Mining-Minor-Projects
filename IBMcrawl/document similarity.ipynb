# %%
import pandas as pd

# %%
year_list = ['2008','2009','2010','2011','2012','2013','2014','2015']

for i in range(0,8):
    previous = []
    if i>0:
        for y in range(0,i):
            datay = set(pd.read_csv("most_50_common_words_"+year_list[y]+'.csv')["word"])
            for y in list(datay):
                if y not in previous:
                    previous.append(y)     
    uniquei = []
    datai = set(pd.read_csv("most_50_common_words_"+year_list[i]+'.csv')["word"])
    print "\nCompare year %d with:\n" % int(year_list[i])
    for j in range(i+1,8):
        dataj = set(pd.read_csv("most_50_common_words_"+year_list[j]+'.csv')['word'])
        print year_list[j],':'
        listj = list(datai.intersection(dataj))
        print list(datai.intersection(dataj)),'\n',"%d common words with year %d" % (len(datai.intersection(dataj)),int(year_list[j]))
        for j in list(dataj):
            if j not in previous:
                previous.append(j)
        
    common = []
    for x in list(datai):
        if x in previous:
            common.append(x)   
    print "\nAll compare:"
    print "%d year has %d words in common with other years. They are as follows:\n%s" % (int(year_list[i]),
                                                                                         len(common),common),'\n'
    for x in list(datai):
        if x not in previous:
            uniquei.append(x)
    print "%d Frequent words unique in year %d:\n%s \n" % (len(uniquei),int(year_list[i]),uniquei)
# Out:
# Compare year 2008 with:
#
# 2009 :
# ['help', 'lotus', 'businesses', 'technology', 'information', 'management', 'service', 'provide', 'support', 'system', 'research', 'access', 'also', 'systems', 'new', 'today', 'available', 'customers', 'business', 'collaboration', 'applications', 'said', 'services', 'data', 'clients', 'security', 'software']
# 27 common words with year 2009
# 2010 :
# ['help', 'businesses', 'technology', 'information', 'said', 'service', 'provide', 'support', 'visit', 'system', 'research', 'access', 'also', 'systems', 'new', 'today', 'customers', 'business', 'collaboration', 'applications', 'management', 'services', 'data', 'clients', 'security', 'software']
# 26 common words with year 2010
# 2011 :
# ...

# %%
year2008 = pd.read_csv("most_50_common_words_"+year_list[0]+'.csv')
year2009= pd.read_csv("most_50_common_words_"+year_list[1]+'.csv')
year2010 = pd.read_csv("most_50_common_words_"+year_list[2]+'.csv')
year2011 = pd.read_csv("most_50_common_words_"+year_list[3]+'.csv')
year2012 = pd.read_csv("most_50_common_words_"+year_list[4]+'.csv')
year2013 = pd.read_csv("most_50_common_words_"+year_list[5]+'.csv')
year2014 = pd.read_csv("most_50_common_words_"+year_list[6]+'.csv')
year2015 = pd.read_csv("most_50_common_words_"+year_list[7]+'.csv')
year2008
# Out:
#              word  2008
# 0        services    48
# 1           lotus    40
# 2        business    35
# 3             new    32
# 4      technology    25
# 5           state    21
# 6     foundations    20
# 7       customers    20
# 8            data    19
# 9         service    19
# 10        support    19
# 11       sametime    18
# 12            vcl    18
# 13       software    18
# 14         system    17
# 15           said    17
# 16          unyte    17
# 17     businesses    16
# 18             nc    16
# 19        clients    15
# 20    information    15
# 21         access    15
# 22   applications    14
# 23           help    13
# 24      idataplex    12
# 25     management    12
# 26  collaboration    12
# 27        virtual    12
# 28          users    12
# 29        centers    11
# 30        systems    11
# 31           also    11
# 32       carolina    11
# 33      available    11
# 34      appliance    11
# 35          power    10
# 36           well    10
# ...

# %%
year2008 = year2008.set_index("word")
year2009 = year2009.set_index("word")
year2010.set_index("word")
year2011.set_index("word")
year2012.set_index("word")
year2013.set_index("word")
year2014.set_index("word")
year2015.set_index("word")
year2008
# Out:
#                2008
# word
# services         48
# lotus            40
# business         35
# new              32
# technology       25
# state            21
# foundations      20
# customers        20
# data             19
# service          19
# support          19
# sametime         18
# vcl              18
# software         18
# system           17
# said             17
# unyte            17
# businesses       16
# nc               16
# clients          15
# information      15
# access           15
# applications     14
# help             13
# idataplex        12
# management       12
# collaboration    12
# virtual          12
# users            12
# centers          11
# systems          11
# also             11
# carolina         11
# available        11
# appliance        11
# power            10
# well             10
# north            10
# students         10
# today             9
# provide           9
# partner           9
# security          9
# companies         8
# ...

# %%
results = year2008.join([year2009])
results
# Out:
#                2008 word  2009
# word
# services         48  NaN   NaN
# lotus            40  NaN   NaN
# business         35  NaN   NaN
# new              32  NaN   NaN
# technology       25  NaN   NaN
# state            21  NaN   NaN
# foundations      20  NaN   NaN
# customers        20  NaN   NaN
# data             19  NaN   NaN
# service          19  NaN   NaN
# support          19  NaN   NaN
# sametime         18  NaN   NaN
# vcl              18  NaN   NaN
# software         18  NaN   NaN
# system           17  NaN   NaN
# said             17  NaN   NaN
# unyte            17  NaN   NaN
# businesses       16  NaN   NaN
# nc               16  NaN   NaN
# clients          15  NaN   NaN
# information      15  NaN   NaN
# access           15  NaN   NaN
# applications     14  NaN   NaN
# help             13  NaN   NaN
# idataplex        12  NaN   NaN
# management       12  NaN   NaN
# collaboration    12  NaN   NaN
# virtual          12  NaN   NaN
# users            12  NaN   NaN
# ...

# %%
year2015.'bluemix'
# Out:
#   File "<ipython-input-46-5ba6aa2dab6a>", line 1
#     year2015.'bluemix'
#                      ^
# SyntaxError: invalid syntax

# %%
 mylist = [u'nowplaying', u'PBS', u'PBS', u'nowplaying', u'job', u'debate', u'thenandnow']
myset = set(mylist)
print myset
pdi
# Out:
# set([u'nowplaying', u'job', u'debate', u'PBS', u'thenandnow'])
#               word  count
# 0             data    493
# 1              new    356
# 2         services    334
# 3           watson    240
# 4         business    212
# 5      information    208
# 6             help    191
# 7          clients    185
# 8             said    179
# 9         platform    177
# 10      technology    169
# 11          global    160
# 12       analytics    155
# 13       solutions    152
# 14         company    145
# 15          health    134
# 16       customers    129
# 17      developers    128
# 18        software    128
# 19         service    126
# 20  infrastructure    123
# 21         storage    123
# 22          mobile    118
# 23          across    116
# 24            also    115
# 25        research    114
# 26         percent    114
# 27           visit    113
# 28           today    109
# 29    applications    109
# 30       including    109
# 31     development    108
# ...

# %%
[x in list(pd_2011["word"]) for x in list(pd_2010["word"])]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False]

# %%
a = set(['b','a'])
b = set(['a'])
a-b
# Out:
# {'b'}
